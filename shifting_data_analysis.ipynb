# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as datetime

df=pd.read_excel(r"C:\Users\91709\OneDrive\Pictures\Documents\Pac_n_mov_customers_data.xlsx")
df
# Out:
#     S.No       Customer_name   Phone_number  whatsapp_number  \
# 0      1        Yogeshwar rao  919492864668     919492864668
# 1      2                  RTY  918500171151     918500171151
# 2      3               Indian  919441694111     919441694111
# 3      4            Janardhan  919505143927     919505143927
# 4      5  Surender Kothapelli  919959699297     919959699297
# ..   ...                  ...           ...              ...
# 61    62            sir/madam  919398165948     919398165948
# 62    63            sir/madam  919642428260     919642428260
# 63    64            sir/madam  918008747032     918008747032
# 64    65            sir/madam  917780535531     917780535531
# 65    66         M Ravi Kumar  919848979345     919848979345
#
#         shifted_from        shifted_To  Price                 Date
# 0   Yadigiri Theatre  Yadigiri Theatre   6000  2024-05-05 00:00:00
# 1                NaN               NaN   6000  2024-05-06 00:00:00
# ...

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['S.No', 'Customer_name', 'Phone_number', 'whatsapp_number',
#        'shifted_from', 'shifted_To', 'Price', 'Date'],
#       dtype='object')

# %%
df['Date']=pd.to_datetime(df['Date'],errors='coerce')
df['yearmonth']=df['Date'].dt.to_period('M')
#new dataframe monthly_data
monthly_data=df.groupby('yearmonth').size().reset_index(name='count')

monthly_data['yearmonth']=monthly_data['yearmonth'].dt.to_timestamp()

# Step 8: Plot the result
plt.figure(figsize=(10, 5))
plt.plot(monthly_data['yearmonth'], monthly_data['count'], marker='^', linestyle='-')     
plt.title('Monthly Records Count')
plt.xlabel('Month')
plt.ylabel('Number of Records')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
monthly_data
# Out:
#     yearmonth  count
# 0  2024-05-01     10
# 1  2024-06-01      4
# 2  2024-07-01      2
# 3  2024-08-01      2
# 4  2024-09-01      3
# 5  2024-10-01      2
# 6  2024-11-01      4
# 7  2024-12-01      7
# 8  2025-01-01      2
# 9  2025-02-01      9
# 10 2025-03-01      2
# 11 2025-04-01      9
# 12 2025-05-01      5
# 13 2025-06-01      3
# 14 2026-06-01      1
