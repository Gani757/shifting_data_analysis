# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_excel(r"C:\Users\91709\OneDrive\Pictures\Documents\Pac_n_mov_customers_data.xlsx")
df
# Out:
#     S.No       Customer_name   Phone_number  whatsapp_number  \
# 0      1        Yogeshwar rao  919492864668     919492864668
# 1      2                  RTY  918500171151     918500171151
# 2      3               Indian  919441694111     919441694111
# 3      4            Janardhan  919505143927     919505143927
# 4      5  Surender Kothapelli  919959699297     919959699297
# ..   ...                  ...           ...              ...
# 72    73          Ammu Dsouza  918328337855     918328337855
# 73    74      Ranjitha Maduri  919505454478     919505454478
# 74    75             Shirisha  919550561742     919550561742
# 75    76            Sir/madam  917386174139     917386174139
# 76    78         Renuka akula  919985836455      91998536455
#
#           shifted_from          shifted_To  Price                 Date  \
# 0     Yadigiri Theatre    Yadigiri Theatre   6000  2024-05-05 00:00:00
# 1                  NaN                 NaN   6000  2024-05-06 00:00:00
# 2                  NaN                 NaN   6000  2024-05-07 00:00:00
# 3                  NaN                 NaN   6000  2024-05-08 00:00:00
# 4         Chilka Nagar               Uppal   3800  2024-08-19 00:00:00
# ..                 ...                 ...    ...                  ...
# 72          Jillelguda         Sainik puri   4800  2025-06-02 00:00:00
# 73            Malakpet          Super Bagh   6000  2025-06-02 00:00:00
# 74    Saraswathi nagar         Turkayemjal   8000  2025-06-02 00:00:00
# 75  Pavan puri colony   Pavan puri colony    2500  2025-06-05 00:00:00
# 76            SAIDABAD            Saidabad   5500  2025-06-02 00:00:00
#
#    Repeat Customer
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ..             ...
# 72              No
# 73              No
# 74              No
# 75              No
# 76              No
#
# [77 rows x 9 columns]

# %% [markdown]
# data exploration

# %%
df.shape
# Out:
# (77, 9)

# %%
df.head()
# Out:
#    S.No       Customer_name   Phone_number  whatsapp_number      shifted_from  \
# 0     1        Yogeshwar rao  919492864668     919492864668  Yadigiri Theatre
# 1     2                  RTY  918500171151     918500171151               NaN
# 2     3               Indian  919441694111     919441694111               NaN
# 3     4            Janardhan  919505143927     919505143927               NaN
# 4     5  Surender Kothapelli  919959699297     919959699297      Chilka Nagar
#
#          shifted_To  Price                 Date Repeat Customer
# 0  Yadigiri Theatre   6000  2024-05-05 00:00:00              No
# 1               NaN   6000  2024-05-06 00:00:00              No
# 2               NaN   6000  2024-05-07 00:00:00              No
# 3               NaN   6000  2024-05-08 00:00:00              No
# 4             Uppal   3800  2024-08-19 00:00:00              No

# %%
df.tail()
# Out:
#     S.No   Customer_name   Phone_number  whatsapp_number        shifted_from  \
# 72    73      Ammu Dsouza  918328337855     918328337855          Jillelguda
# 73    74  Ranjitha Maduri  919505454478     919505454478            Malakpet
# 74    75         Shirisha  919550561742     919550561742    Saraswathi nagar
# 75    76        Sir/madam  917386174139     917386174139  Pavan puri colony
# 76    78     Renuka akula  919985836455      91998536455            SAIDABAD
#
#             shifted_To  Price                 Date Repeat Customer
# 72         Sainik puri   4800  2025-06-02 00:00:00              No
# 73          Super Bagh   6000  2025-06-02 00:00:00              No
# 74         Turkayemjal   8000  2025-06-02 00:00:00              No
# 75  Pavan puri colony    2500  2025-06-05 00:00:00              No
# 76            Saidabad   5500  2025-06-02 00:00:00              No

# %%
df.describe()   #statistical summary
# Out:
#             S.No  Phone_number  whatsapp_number         Price
# count  77.000000  7.700000e+01     7.700000e+01     77.000000
# mean   39.012987  9.189541e+11     9.082010e+11   6588.961039
# std    22.394486  9.567263e+08     9.424356e+10   2919.203922
# min     1.000000  9.162815e+11     9.199854e+10   1150.000000
# 25%    20.000000  9.183283e+11     9.183282e+11   5000.000000
# 50%    39.000000  9.191778e+11     9.191540e+11   6000.000000
# 75%    58.000000  9.196424e+11     9.196424e+11   7500.000000
# max    78.000000  9.199904e+11     9.199904e+11  15000.000000

# %%
df.columns=df.columns.str.strip().str.lower()    #cleaned column name and  converted to lower
df.columns
# Out:
# Index(['s.no', 'customer_name', 'phone_number', 'whatsapp_number',
#        'shifted_from', 'shifted_to', 'price', 'date', 'repeat customer'],
#       dtype='object')

# %%
df["customer_name"]=df["customer_name"].str.strip().str.title()
df["shifted_from"]=df["shifted_from"].str.strip().str.title()
df["shifted_to"]=df["shifted_to"].str.strip().str.title()
df["repeat customer"]=df["repeat customer"].str.strip().str.title()
df
# Out:
#     s.no        customer_name  phone_number  whatsapp_number  \
# 0      1        Yogeshwar Rao  919492864668     919492864668
# 1      2                  Rty  918500171151     918500171151
# 2      3               Indian  919441694111     919441694111
# 3      4            Janardhan  919505143927     919505143927
# 4      5  Surender Kothapelli  919959699297     919959699297
# ..   ...                  ...           ...              ...
# 72    73          Ammu Dsouza  918328337855     918328337855
# 73    74      Ranjitha Maduri  919505454478     919505454478
# 74    75             Shirisha  919550561742     919550561742
# 75    76            Sir/Madam  917386174139     917386174139
# 76    78         Renuka Akula  919985836455      91998536455
#
#          shifted_from         shifted_to  price                 date  \
# 0    Yadigiri Theatre   Yadigiri Theatre   6000  2024-05-05 00:00:00
# 1                 NaN                NaN   6000  2024-05-06 00:00:00
# 2                 NaN                NaN   6000  2024-05-07 00:00:00
# 3                 NaN                NaN   6000  2024-05-08 00:00:00
# 4        Chilka Nagar              Uppal   3800  2024-08-19 00:00:00
# ..                ...                ...    ...                  ...
# 72         Jillelguda        Sainik Puri   4800  2025-06-02 00:00:00
# 73           Malakpet         Super Bagh   6000  2025-06-02 00:00:00
# 74   Saraswathi Nagar        Turkayemjal   8000  2025-06-02 00:00:00
# 75  Pavan Puri Colony  Pavan Puri Colony   2500  2025-06-05 00:00:00
# 76           Saidabad           Saidabad   5500  2025-06-02 00:00:00
#
#    repeat customer
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ..             ...
# 72              No
# 73              No
# 74              No
# 75              No
# 76              No
#
# [77 rows x 9 columns]

# %% [markdown]
# # Data exploration:(remove or replace)
# -
# > check wrong data
# >
# > check wrong data type
# >
# > check missing values
# >
# > check duplicates

# %%
print(df['s.no'].nunique())
print(df['customer_name'].unique())
print(df['phone_number'].nunique())
print(df['whatsapp_number'].nunique())
print(df['shifted_from'].nunique())
print(df['shifted_to'].nunique())
print(df['date'].nunique())
print(df['repeat customer'].unique())
# Out:
# 77
# ['Yogeshwar Rao' 'Rty' 'Indian' 'Janardhan' 'Surender Kothapelli'
#  'Kannaiah Vk' 'Pramod Reddy Tippani' 'Sir/Madam' 'Patlolla Rukma Reddy'
#  'N Ramesh' 'Sumana Sree' 'Venkatesh' 'Ananda Rao' 'Arjun K' 'Vikas Rai'
#  'Konda Raghava Reddy' 'Ali' 'Aditya Tirumala' 'Sravan Kumar' 'Madhu Ch'
#  'Vinay' 'Tanishq Raj' 'M Ravi Kumar' 'Chennoju Vani' 'Anil' 'Naresh'
#  'Deepthi' 'Ammu Dsouza' 'Ranjitha Maduri' 'Shirisha' 'Renuka Akula']
# 75
# 75
# 54
# 60
# 59
# ['No' 'Yes']

# %%
df
# Out:
#     s.no        customer_name  phone_number  whatsapp_number  \
# 0      1        Yogeshwar Rao  919492864668     919492864668
# 1      2                  Rty  918500171151     918500171151
# 2      3               Indian  919441694111     919441694111
# 3      4            Janardhan  919505143927     919505143927
# 4      5  Surender Kothapelli  919959699297     919959699297
# ..   ...                  ...           ...              ...
# 72    73          Ammu Dsouza  918328337855     918328337855
# 73    74      Ranjitha Maduri  919505454478     919505454478
# 74    75             Shirisha  919550561742     919550561742
# 75    76            Sir/Madam  917386174139     917386174139
# 76    78         Renuka Akula  919985836455      91998536455
#
#          shifted_from         shifted_to  price                 date  \
# 0    Yadigiri Theatre   Yadigiri Theatre   6000  2024-05-05 00:00:00
# 1                 NaN                NaN   6000  2024-05-06 00:00:00
# 2                 NaN                NaN   6000  2024-05-07 00:00:00
# 3                 NaN                NaN   6000  2024-05-08 00:00:00
# 4        Chilka Nagar              Uppal   3800  2024-08-19 00:00:00
# ..                ...                ...    ...                  ...
# 72         Jillelguda        Sainik Puri   4800  2025-06-02 00:00:00
# 73           Malakpet         Super Bagh   6000  2025-06-02 00:00:00
# 74   Saraswathi Nagar        Turkayemjal   8000  2025-06-02 00:00:00
# 75  Pavan Puri Colony  Pavan Puri Colony   2500  2025-06-05 00:00:00
# 76           Saidabad           Saidabad   5500  2025-06-02 00:00:00
#
#    repeat customer
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ..             ...
# 72              No
# 73              No
# 74              No
# 75              No
# 76              No
#
# [77 rows x 9 columns]

# %%
df.dtypes
# Out:
# s.no                int64
# customer_name      object
# phone_number        int64
# whatsapp_number     int64
# shifted_from       object
# shifted_to         object
# price               int64
# date               object
# repeat customer    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# s.no               0
# customer_name      0
# phone_number       0
# whatsapp_number    0
# shifted_from       3
# shifted_to         4
# price              0
# date               0
# repeat customer    0
# dtype: int64

# %% [markdown]
# outliers

# %%
df=df.drop("s.no",axis=1)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(df["price"])
plt.show()

# %%
Q1=df["price"].quantile(0.25)
Q3=df["price"].quantile(0.75)
IQR=Q3-Q1
ll=Q1-(1.5*IQR)
ul=Q3+(1.5*IQR)
oultiers=df[(df["price"]<ll) | (df["price"]>ul)].reset_index(drop=True)
oultiers
# Out:
#          customer_name  phone_number  whatsapp_number shifted_from  \
# 0            Sir/Madam  916300982495     916300982495     Saidabad
# 1  Konda Raghava Reddy  919391010766     919391010766     Kondapur
# 2            Sir/Madam  918008380115     918008380115         Bhel
# 3            Sir/Madam  919959499977     919959499977        Uppal
# 4            Sir/Madam  919985996164     919985996164    Nalagonda
# 5            Sir/Madam  919642176342     919642176342  Saroornagar
# 6            Sir/Madam  918465010138     918465010138  Saroornagar
# 7            Sir/Madam  919985996164     919985996164    Nalagonda
# 8         M Ravi Kumar  919848979345     919848979345     Saidabad
#
#       shifted_to  price                 date repeat customer
# 0       Kompally   1150  2024-06-20 00:00:00              No
# 1      Mohenabad  15000  2024-09-08 00:00:00              No
# 2       Kothapet  14000  2025-01-11 00:00:00              No
# 3  Manchirya -La  12000  2025-02-02 00:00:00              No
# 4    Manchurabad  15000  2025-04-03 00:00:00             Yes
# 5    Meeryalguda  13500  2025-04-23 00:00:00              No
# 6    Meeryalguda  13500  2025-04-24 00:00:00              No
# 7     Karmanghat  12000  2025-04-27 00:00:00             Yes
# 8        Moulali  12000  2025-06-01 00:00:00              No

# %%
oultiers.shape    #here 69 records of outliers
# Out:
# (9, 8)

# %%
sns.histplot(df["price"])
plt.show()

# %% [markdown]
# data cleaning

# %%
#Count plot of repeat customers
sns.countplot(x=df["repeat customer"])
plt.show()

# %%
df.columns
# Out:
# Index(['customer_name', 'phone_number', 'whatsapp_number', 'shifted_from',
#        'shifted_to', 'price', 'date', 'repeat customer'],
#       dtype='object')

# %%
df["shifted_from"]=df["shifted_from"].fillna(df["shifted_from"].mode()[0])
df["shifted_to"]=df["shifted_to"].fillna(df["shifted_to"].mode()[0])
df.isnull().sum()                #treated missing values
# Out:
# customer_name      0
# phone_number       0
# whatsapp_number    0
# shifted_from       0
# shifted_to         0
# price              0
# date               0
# repeat customer    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["date"]=pd.to_datetime(df["date"],errors="coerce")
df["yearmonth"]=df["date"].dt.to_period("M")
monthly_data=df.groupby("yearmonth")["yearmonth"].agg(count="count").reset_index()

#convert to timestamp for plotting 
monthly_data["yearmonth"]=monthly_data["yearmonth"].dt.to_timestamp()

#sns.relplot(data=monthly_data,x="yearmonth",y="count",kind="line")

# Monthly trend 
plt.plot(monthly_data["yearmonth"],monthly_data["count"])
plt.title("monthly shifting records")
plt.xlabel("month of shifiting")
plt.ylabel("number of shifitings")
plt.xticks(rotation=45)
plt.show()

# %%
monthly_data
# Out:
#     yearmonth  count
# 0  2024-05-01     10
# 1  2024-06-01      4
# 2  2024-07-01      2
# 3  2024-08-01      2
# 4  2024-09-01      3
# 5  2024-10-01      2
# 6  2024-11-01      4
# 7  2024-12-01      7
# 8  2025-01-01      2
# 9  2025-02-01      9
# 10 2025-03-01      2
# 11 2025-04-01      9
# 12 2025-05-01      8
# 13 2025-06-01     11
# 14 2026-06-01      1

# %%
df.columns=df.columns.str.strip().str.title()
df
# Out:
#           Customer_Name  Phone_Number  Whatsapp_Number       Shifted_From  \
# 0         Yogeshwar Rao  919492864668     919492864668   Yadigiri Theatre
# 1                   Rty  918500171151     918500171151         Karmanghat
# 2                Indian  919441694111     919441694111         Karmanghat
# 3             Janardhan  919505143927     919505143927         Karmanghat
# 4   Surender Kothapelli  919959699297     919959699297       Chilka Nagar
# ..                  ...           ...              ...                ...
# 72          Ammu Dsouza  918328337855     918328337855         Jillelguda
# 73      Ranjitha Maduri  919505454478     919505454478           Malakpet
# 74             Shirisha  919550561742     919550561742   Saraswathi Nagar
# 75            Sir/Madam  917386174139     917386174139  Pavan Puri Colony
# 76         Renuka Akula  919985836455      91998536455           Saidabad
#
#            Shifted_To  Price       Date Repeat Customer Yearmonth
# 0    Yadigiri Theatre   6000 2024-05-05              No   2024-05
# 1          Karmanghat   6000 2024-05-06              No   2024-05
# 2          Karmanghat   6000 2024-05-07              No   2024-05
# 3          Karmanghat   6000 2024-05-08              No   2024-05
# 4               Uppal   3800 2024-08-19              No   2024-08
# ..                ...    ...        ...             ...       ...
# 72        Sainik Puri   4800 2025-06-02              No   2025-06
# 73         Super Bagh   6000 2025-06-02              No   2025-06
# 74        Turkayemjal   8000 2025-06-02              No   2025-06
# 75  Pavan Puri Colony   2500 2025-06-05              No   2025-06
# 76           Saidabad   5500 2025-06-02              No   2025-06
#
# [77 rows x 9 columns]

# %%
df.to_excel("cleaned_shifting_data.xlsx")

# %%
✅ Completed Data Cleaning Steps:

Loaded and viewed data (head(), tail()).

Cleaned column names (removed spaces, lowercased).

Filled missing values using mode() for categorical columns.

Dropped irrelevant column (s.no).

Checked for duplicates and nulls.

Handled outliers using IQR (with correction).

Standardized textual columns (customer_name, shifted_from, etc.).

Visualized distribution with boxplot and histogram.

Converted date column to datetime format.

Exported cleaned data .
